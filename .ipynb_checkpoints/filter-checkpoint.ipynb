# 4499  109432832.0  164239360.0  31735808.0  27312128.0  182061056.0
#
#                T4            A2  IMPEDANCE  BATTERY   FRAME
# 0     204752896.0  4.268970e+09       17.0    106.0     0.0
# 1     198785024.0  4.264511e+09       17.0    106.0     1.0
# 2     210755584.0  4.276103e+09       17.0    106.0     2.0
# 3     216682496.0  4.280531e+09       17.0    106.0     3.0
# 4     204658688.0  4.268884e+09       17.0    106.0     4.0
# ...           ...           ...        ...      ...     ...
# 4495  215025664.0  4.280136e+09       17.0    106.0  4495.0
# 4496  203593728.0  4.268943e+09       17.0    106.0  4496.0
# 4497  198070272.0  4.264794e+09       17.0    106.0  4497.0
# 4498  209510400.0  4.275964e+09       17.0    106.0  4498.0
# 4499  215060480.0  4.280103e+09       17.0    106.0  4499.0
#
# [4500 rows x 24 columns]

# %%
dfO1 = df.loc[:, "O1"]
O1 = dfO1.to_numpy()

# %%
x = np.arange(4500) / 500

# %%
plt.plot(x, O1)

# %%
dfF8 = df.loc[:, "F8"]
F8 = dfF8.to_numpy()

# %%
plt.plot(x, F8)

# %%
f, Pxx_den = signal.welch(O1, 500)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD')
plt.show()

# %%
b, a = signal.iirfilter(20, Wn=45, fs=500, btype="low", ftype="butter")

# %%
O1Filtered = signal.lfilter(b, a, O1)

# %%
b, a = signal.iirfilter(20, Wn=0.5, fs=500, btype="high", ftype="butter")

# %%
O1Filtered = signal.lfilter(b, a, O1Filtered)

# %%
f, Pxx_den = signal.welch(O1Filtered, 500)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD')
plt.show()
# Out:
# /home/ivan/miniconda3/lib/python3.9/site-packages/scipy/signal/_spectral_py.py:1878: RuntimeWarning: overflow encountered in multiply
#   result = np.conjugate(result) * result
# /home/ivan/miniconda3/lib/python3.9/site-packages/scipy/signal/_spectral_py.py:1878: RuntimeWarning: invalid value encountered in multiply
#   result = np.conjugate(result) * result
# /home/ivan/miniconda3/lib/python3.9/site-packages/scipy/signal/_spectral_py.py:1880: RuntimeWarning: invalid value encountered in multiply
#   result *= scale

# %%
plt.plot(x, O1Filtered)

# %%
plt.plot(x[200:], O1Filtered[200:])

# %%
srate = 500
n_cycles = 80
frex = 12
width = 4 # seconds

cmw = morlet_wavelet(srate, n_cycles, frex, width)

time = np.arange(0, width * srate) / srate
time = time - np.mean(time)

plt.plot(time, np.real(cmw))
plt.show()
